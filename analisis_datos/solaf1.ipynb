# %% [markdown]
# # Actividad Formativa 1: Análisis de datos del Titanic
# En esta actividad, analizaremos el conjunto de datos del Titanic para responder a preguntas sobre la supervivencia de los pasajeros. Utilizaremos Python y bibliotecas como Pandas y Matplotlib para realizar el análisis.
#
#  ## Objetivos:
# - Cargar y explorar el conjunto de datos del Titanic.
# - Realizar análisis descriptivos y cuantitativos sobre la supervivencia de los pasajeros.
#
# ## Descripcción del conjunto de datos:
# El conjunto de datos del Titanic contiene información sobre los pasajeros del famoso transatlántico que se hundió en 1912. Incluye columnas como:
#
# - Id_Pasajero: Id de cada pasajero.
#
# - Survived: esta característica tiene valor 0 y 1. 0 para no sobrevivió y 1 para sobrevi.
#
# - Clase: Hay 3 clases: Clase 1, Clase 2 y Clase 3.
#
# - Nombre: Nombre del pasajero.
#
# - Sexo: Género del pasajero.
#
# - Edad: Edad del pasajero.
#
# - Familiares: numero de familiares del pasajero.
#
# - Ticket: Número de ticket del pasajero.
#
# - Tarifa: Indicando la tarifa.
#
# - Cabina: La cabina del pasajero.
#
# - Embarcado: La categoría embarcada.

# %% [markdown]
# ### 1. Importa las bibliotecas necesarias: pandas y matplotlib.

# %%
import pandas as pd

# %% [markdown]
# ### 2. Carga el conjunto de datos del Titanic y asignale el nombre `titanic`.

# %%
titanic = pd.read_excel("titanic.xlsx")

# %% [markdown]
# ### 3. Muestra las primeras 5 filas del conjunto de datos.

# %%
titanic.head(5)
# Out:
#    Id_Pasajero  Survived  Clase  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                               Nombre       Sexo  Edad  \
# 0                            Braund, Mr. Owen Harris  Masculino  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                             Heikkinen, Miss. Laina   Femenino  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                           Allen, Mr. William Henry  Masculino  35.0
#
#    Familiares           Tiquete  Tarifa Cabina Embarcado
# 0           0         A/5 21171    7.25    NaN         S
# 1           0          PC 17599   71.28    C85         C
# 2           0  STON/O2. 3101282    7.93    NaN         S
# 3           0            113803   53.10   C123         S
# 4           0            373450    8.05    NaN         S

# %% [markdown]
# ### 4. Muestra las 10 útimas filas del conjunto de datos.

# %%
titanic.tail(10)
# Out:
#      Id_Pasajero  Survived  Clase                                    Nombre  \
# 881          882         0      3                        Markun, Mr. Johann
# 882          883         0      3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0      2             Banfield, Mr. Frederick James
# 884          885         0      3                    Sutehall, Mr. Henry Jr
# 885          886         0      3      Rice, Mrs. William (Margaret Norton)
# 886          887         0      2                     Montvila, Rev. Juozas
# 887          888         1      1              Graham, Miss. Margaret Edith
# 888          889         0      3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1      1                     Behr, Mr. Karl Howell
# 890          891         0      3                       Dooley, Mr. Patrick
#
#           Sexo  Edad  Familiares           Tiquete  Tarifa Cabina Embarcado
# 881  Masculino  33.0           0            349257    7.90    NaN         S
# 882   Femenino  22.0           0              7552   10.52    NaN         S
# 883  Masculino  28.0           0  C.A./SOTON 34068   10.50    NaN         S
# 884  Masculino  25.0           0   SOTON/OQ 392076    7.05    NaN         S
# 885   Femenino  39.0           5            382652   29.13    NaN         Q
# 886  Masculino  27.0           0            211536   13.00    NaN         S
# 887   Femenino  19.0           0            112053   30.00    B42         S
# 888   Femenino   NaN           2        W./C. 6607   23.45    NaN         S
# 889  Masculino  26.0           0            111369   30.00   C148         C
# 890  Masculino  32.0           0            370376    7.75    NaN         Q

# %% [markdown]
# ### 5. Muestra la información general del conjunto de datos.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id_Pasajero  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Clase        891 non-null    int64
#  3   Nombre       891 non-null    object
#  4   Sexo         891 non-null    object
#  5   Edad         714 non-null    float64
#  6   Familiares   891 non-null    int64
#  7   Tiquete      891 non-null    object
#  8   Tarifa       891 non-null    float64
#  9   Cabina       204 non-null    object
#  10  Embarcado    889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %% [markdown]
# ### 6. ¿Cuántas filas hay en total?

# %%
titanic.shape[0]
# Out:
# 891

# %% [markdown]
# ### 7. ¿Cuántas columnnas hay en total?.

# %%
titanic.shape[1]
# Out:
# 11

# %% [markdown]
# ### 8. Muestra las columnnas del dataframe.

# %%
titanic.columns
# Out:
# Index(['Id_Pasajero', 'Survived', 'Clase', 'Nombre', 'Sexo', 'Edad',
#        'Familiares', 'Tiquete', 'Tarifa', 'Cabina', 'Embarcado'],
#       dtype='object')

# %% [markdown]
# ### 9. Muestra sólo los datos de los hombres y nombra a este nuevo dataframe hombres.

# %%
hombres = titanic[titanic["Sexo"]=="Masculino"]
hombres
# Out:
#      Id_Pasajero  Survived  Clase                          Nombre       Sexo  \
# 0              1         0      3         Braund, Mr. Owen Harris  Masculino
# 4              5         0      3        Allen, Mr. William Henry  Masculino
# 5              6         0      3                Moran, Mr. James  Masculino
# 6              7         0      1         McCarthy, Mr. Timothy J  Masculino
# 7              8         0      3  Palsson, Master. Gosta Leonard  Masculino
# ..           ...       ...    ...                             ...        ...
# 883          884         0      2   Banfield, Mr. Frederick James  Masculino
# 884          885         0      3          Sutehall, Mr. Henry Jr  Masculino
# 886          887         0      2           Montvila, Rev. Juozas  Masculino
# 889          890         1      1           Behr, Mr. Karl Howell  Masculino
# 890          891         0      3             Dooley, Mr. Patrick  Masculino
#
#      Edad  Familiares           Tiquete  Tarifa Cabina Embarcado
# 0    22.0           0         A/5 21171    7.25    NaN         S
# 4    35.0           0            373450    8.05    NaN         S
# 5     NaN           0            330877    8.46    NaN         Q
# 6    54.0           0             17463   51.86    E46         S
# 7     2.0           1            349909   21.08    NaN         S
# ..    ...         ...               ...     ...    ...       ...
# 883  28.0           0  C.A./SOTON 34068   10.50    NaN         S
# 884  25.0           0   SOTON/OQ 392076    7.05    NaN         S
# 886  27.0           0            211536   13.00    NaN         S
# 889  26.0           0            111369   30.00   C148         C
# 890  32.0           0            370376    7.75    NaN         Q
#
# [577 rows x 11 columns]

# %% [markdown]
# ### 10. Muestra sólo los datos de las mujeres y nombra a este nuevo dataframe mujeres.

# %%
mujeres = titanic[titanic["Sexo"]=="Femenino"]
mujeres
# Out:
#      Id_Pasajero  Survived  Clase  \
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 8              9         1      3
# 9             10         1      2
# ..           ...       ...    ...
# 880          881         1      2
# 882          883         0      3
# 885          886         0      3
# 887          888         1      1
# 888          889         0      3
#
#                                                 Nombre      Sexo  Edad  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Femenino  38.0
# 2                               Heikkinen, Miss. Laina  Femenino  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Femenino  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Femenino  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  Femenino  14.0
# ..                                                 ...       ...   ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  Femenino  25.0
# 882                       Dahlberg, Miss. Gerda Ulrika  Femenino  22.0
# 885               Rice, Mrs. William (Margaret Norton)  Femenino  39.0
# 887                       Graham, Miss. Margaret Edith  Femenino  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Femenino   NaN
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 1             0          PC 17599   71.28    C85         C
# 2             0  STON/O2. 3101282    7.93    NaN         S
# 3             0            113803   53.10   C123         S
# 8             2            347742   11.13    NaN         S
# 9             0            237736   30.07    NaN         C
# ..          ...               ...     ...    ...       ...
# 880           1            230433   26.00    NaN         S
# 882           0              7552   10.52    NaN         S
# 885           5            382652   29.13    NaN         Q
# 887           0            112053   30.00    B42         S
# 888           2        W./C. 6607   23.45    NaN         S
#
# [314 rows x 11 columns]

# %% [markdown]
# ### 11. Muestra sólo los datos de las peronas menores de 18 años.

# %%
titanic[titanic["Edad"]<18]
# Out:
#      Id_Pasajero  Survived  Clase                                   Nombre  \
# 7              8         0      3           Palsson, Master. Gosta Leonard
# 9             10         1      2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1      3          Sandstrom, Miss. Marguerite Rut
# 14            15         0      3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0      3                     Rice, Master. Eugene
# ..           ...       ...    ...                                      ...
# 850          851         0      3  Andersson, Master. Sigvard Harald Elias
# 852          853         0      3                  Boulos, Miss. Nourelain
# 853          854         1      1                Lines, Miss. Mary Conover
# 869          870         1      3          Johnson, Master. Harold Theodor
# 875          876         1      3         Najib, Miss. Adele Kiamie "Jane"
#
#           Sexo  Edad  Familiares   Tiquete  Tarifa Cabina Embarcado
# 7    Masculino   2.0           1    349909   21.08    NaN         S
# 9     Femenino  14.0           0    237736   30.07    NaN         C
# 10    Femenino   4.0           1   PP 9549   16.70     G6         S
# 14    Femenino  14.0           0    350406    7.85    NaN         S
# 16   Masculino   2.0           1    382652   29.13    NaN         Q
# ..         ...   ...         ...       ...     ...    ...       ...
# 850  Masculino   4.0           2    347082   31.28    NaN         S
# 852   Femenino   9.0           1      2678   15.25    NaN         C
# 853   Femenino  16.0           1  PC 17592   39.40    D28         S
# 869  Masculino   4.0           1    347742   11.13    NaN         S
# 875   Femenino  15.0           0      2667    7.23    NaN         C
#
# [113 rows x 11 columns]

# %% [markdown]
# ### 12. Calcula la edad promedio de los pasajeros.

# %%
titanic["Edad"].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# ### 13. Calcula la edad promedio de los pasajeros menore de 18 años.

# %% [markdown]
# ### 14. Muestra los datos de las personas de las clases 1 y 2.

# %%
titanic[(titanic["Clase"]==1) | (titanic["Clase"]==2)]
# Out:
#      Id_Pasajero  Survived  Clase  \
# 1              2         1      1
# 3              4         1      1
# 6              7         0      1
# 9             10         1      2
# 11            12         1      1
# ..           ...       ...    ...
# 880          881         1      2
# 883          884         0      2
# 886          887         0      2
# 887          888         1      1
# 889          890         1      1
#
#                                                 Nombre       Sexo  Edad  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 6                              McCarthy, Mr. Timothy J  Masculino  54.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)   Femenino  14.0
# 11                            Bonnell, Miss. Elizabeth   Femenino  58.0
# ..                                                 ...        ...   ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)   Femenino  25.0
# 883                      Banfield, Mr. Frederick James  Masculino  28.0
# 886                              Montvila, Rev. Juozas  Masculino  27.0
# 887                       Graham, Miss. Margaret Edith   Femenino  19.0
# 889                              Behr, Mr. Karl Howell  Masculino  26.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 1             0          PC 17599   71.28    C85         C
# 3             0            113803   53.10   C123         S
# 6             0             17463   51.86    E46         S
# 9             0            237736   30.07    NaN         C
# 11            0            113783   26.55   C103         S
# ..          ...               ...     ...    ...       ...
# 880           1            230433   26.00    NaN         S
# 883           0  C.A./SOTON 34068   10.50    NaN         S
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 889           0            111369   30.00   C148         C
#
# [400 rows x 11 columns]

# %% [markdown]
# ### 15. Muestra los datos de las personas que registraron su edad al abordar.

# %%
# Recuerda .isna() determina si hay nulos, en este caso aplicado a una columna, el método chequea cada elemento de la columna y determina si es na. Lo mismo ocurre con el método .notna() para los elementos no nulos.
titanic[titanic["Edad"].notna()]
# Out:
#      Id_Pasajero  Survived  Clase  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 885          886         0      3
# 886          887         0      2
# 887          888         1      1
# 889          890         1      1
# 890          891         0      3
#
#                                                 Nombre       Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris  Masculino  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                               Heikkinen, Miss. Laina   Femenino  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                             Allen, Mr. William Henry  Masculino  35.0
# ..                                                 ...        ...   ...
# 885               Rice, Mrs. William (Margaret Norton)   Femenino  39.0
# 886                              Montvila, Rev. Juozas  Masculino  27.0
# 887                       Graham, Miss. Margaret Edith   Femenino  19.0
# 889                              Behr, Mr. Karl Howell  Masculino  26.0
# 890                                Dooley, Mr. Patrick  Masculino  32.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 0             0         A/5 21171    7.25    NaN         S
# 1             0          PC 17599   71.28    C85         C
# 2             0  STON/O2. 3101282    7.93    NaN         S
# 3             0            113803   53.10   C123         S
# 4             0            373450    8.05    NaN         S
# ..          ...               ...     ...    ...       ...
# 885           5            382652   29.13    NaN         Q
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 889           0            111369   30.00   C148         C
# 890           0            370376    7.75    NaN         Q
#
# [714 rows x 11 columns]

# %% [markdown]
# ### 16. Muestra los nombre de los pasajeros mayores de 30 años que sobrevivieron al naufragio.

# %%
titanic[(titanic["Edad"]>30) & (titanic["Survived"]==1)][["Nombre"]]
# Out:
#                                                 Nombre
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 11                            Bonnell, Miss. Elizabeth
# 15                    Hewlett, Mrs. (Mary D Kingcome)
# 21                               Beesley, Mr. Lawrence
# ..                                                 ...
# 857                             Daly, Mr. Peter Denis
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 865                           Bystrom, Mrs. (Karolina)
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
#
# [124 rows x 1 columns]

# %% [markdown]
# ### 17.  Calcula el promedio de edad de los pasajeron que sobrevivieron.

# %%
titanic[titanic["Survived"]==1]["Edad"].mean()
# Out:
# 28.343689655172415

# %% [markdown]
# ### 18. Agrupa los datos por sexo y calcula la edad promedio de cada grupo.

# %%
titanic.groupby("Sexo")["Edad"].mean()
# Out:
# Sexo
# Femenino     27.915709
# Masculino    30.726645
# Name: Edad, dtype: float64

# %% [markdown]
# ### 19.  Agrupa los datos por clase y calcula  el promedio de edad de los pasajeros en cada clase.

# %%
titanic.groupby("Clase")["Edad"].mean()
# Out:
# Clase
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Edad, dtype: float64

# %% [markdown]
# ### 20. ¿Cuántos pasajeros que no registraron su edad?. ¿Cuántos de ellos sobrevieron?.

# %%
# ¿Cuántos no registraron sue edad?
titanic["Edad"].isna().sum()
# Out:
# 177

# %%
# ¿Cuántos de los que no resgistraon su edad sobrevivieron?
df_pasajeron_sin_edad = titanic[titanic["Edad"].isna()]
df_pasajeron_sin_edad["Survived"].sum()
# Out:
# 52

# %% [markdown]
# ### 21. ¿Cuál fue la edad máxima y mínima de los pasajeros que no sobrevivieron?

# %%
edad_max_no_sobrevive = titanic[titanic["Survived"]==0]["Edad"].max()
edad_max_no_sobrevive
# Out:
# 74.0

# %%
edad_min_no_sobrevive= titanic[titanic["Survived"]==0]["Edad"].min()
edad_min_no_sobrevive
# Out:
# 1.0

# %% [markdown]
# ### 22. ¿Cuál fue la edad máxima y mínima de los pasajeros que sobrevivieron?

# %%
edad_max_sobrevive = titanic[titanic["Survived"]==1]["Edad"].max()
edad_max_sobrevive
# Out:
# 80.0

# %%
edad_min_sobrevive = titanic[titanic["Survived"]==1]["Edad"].min()
edad_min_sobrevive
# Out:
# 0.42

# %% [markdown]
# 23. ### ¿Cuál fue el porcentaje de supervivencia de los pasajeros del Titanic?

# %%
porcentaje_sobrevive= titanic[titanic["Survived"]==1].shape[0] / titanic.shape[0] * 100
porcentaje_sobrevive
# Out:
# 38.38383838383838

# %% [markdown]
# ### 24.  Construye la gráfica de dispersion de `edad` y `tarifa`.

# %%
import matplotlib.pyplot as plt
titanic.plot(kind = 'scatter', x = 'Edad', y = 'Tarifa')
# Out:
# <Axes: xlabel='Edad', ylabel='Tarifa'>

# %% [markdown]
# ### 25. Elimina las filas que tienen datos faltantes en las columnas `edad` y `tarifa`.

# %%
titanic.dropna(subset = ["Edad", "Tarifa"])
# Out:
#      Id_Pasajero  Survived  Clase  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 885          886         0      3
# 886          887         0      2
# 887          888         1      1
# 889          890         1      1
# 890          891         0      3
#
#                                                 Nombre       Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris  Masculino  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                               Heikkinen, Miss. Laina   Femenino  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                             Allen, Mr. William Henry  Masculino  35.0
# ..                                                 ...        ...   ...
# 885               Rice, Mrs. William (Margaret Norton)   Femenino  39.0
# 886                              Montvila, Rev. Juozas  Masculino  27.0
# 887                       Graham, Miss. Margaret Edith   Femenino  19.0
# 889                              Behr, Mr. Karl Howell  Masculino  26.0
# 890                                Dooley, Mr. Patrick  Masculino  32.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 0             0         A/5 21171    7.25    NaN         S
# 1             0          PC 17599   71.28    C85         C
# 2             0  STON/O2. 3101282    7.93    NaN         S
# 3             0            113803   53.10   C123         S
# 4             0            373450    8.05    NaN         S
# ..          ...               ...     ...    ...       ...
# 885           5            382652   29.13    NaN         Q
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 889           0            111369   30.00   C148         C
# 890           0            370376    7.75    NaN         Q
#
# [714 rows x 11 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
